# %%
# `pandas` for data loading/transformations
import pandas as pd

# `seaborn` for visualization
import seaborn as sns

# `matplotlib` for customizing visuals
import matplotlib.pyplot as plt
# %matplotlib inline

# `numpy` for manipulating arrays/lists
import numpy as np

# %%
# # UNCOMMENT BELOW TO USE WITH GOOGLE COLAB
# # Import PyDrive and associated libraries.
# # This only needs to be done once per notebook.
# # Documentation found here: https://colab.research.google.com/notebooks/io.ipynb#scrollTo=7taylj9wpsA2
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials

# # Authenticate and create the PyDrive client.
# # This only needs to be done once per notebook.
# auth.authenticate_user()
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# %%
# # UNCOMMENT BELOW TO USE WITH GOOGLE COLAB
# # Link to data file stored in Drive: https://drive.google.com/file/d/18ut1gQQ65aoQeV0iUQlneNhecpGR51dz/view?usp=sharing
# file_id = '18ut1gQQ65aoQeV0iUQlneNhecpGR51dz' # notice where this string comes from in link above

# imported_file = drive.CreateFile({'id': file_id}) # creating an accessible copy of the shared data file
# print(imported_file['title'])  # it should print the title of desired file
# imported_file.GetContentFile(imported_file['title']) # refer to it in this notebook by the same name as it has in Drive

# %%
# load our data
ppp_data = pd.read_csv('../datasets/public_150k_plus_borrower_fingerprint_a.csv')

# %%
# first, sanity check our data
print(ppp_data[ppp_data['JobsReported'] <= 0])

# drop the records with no value in `JobsReported`
ppp_data.drop(labels=[437083,765398], axis=0)
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 437083  5780187005   04/06/2020            766              PPP
# 765398  4563247009   04/03/2020            897              PPP
#
#                         BorrowerName                BorrowerNameFingerprint  \
# 437083  RELIANT TRANSPORTATION, INC.  inc reliant transportation lincoln NE
# 765398       WEEDEN CONSTRUCTION LLC      construction llc weeden banner WY
#
#             BorrowerAddress BorrowerCity BorrowerState BorrowerZip  ...  \
# 437083   4411 S 86th Street      Lincoln            NE  68526-9225  ...
# 765398  402 MURPHY GULCH RD       BANNER            WY  82832-9726  ...
#
#        HEALTH_CARE_PROCEED DEBT_INTEREST_PROCEED  \
# 437083                 NaN                   NaN
# 765398                 NaN                   NaN
#
#                            BusinessType  OriginatingLenderLocationID  \
# 437083                      Corporation                        42246
# 765398  Limited  Liability Company(LLC)                        87893
#
#                 OriginatingLender  OriginatingLenderCity  \
# 437083  First State Bank Nebraska                LINCOLN
# 765398               Glacier Bank              KALISPELL
#
#         OriginatingLenderState      Gender     Veteran NonProfit
# 437083                      NE  Male Owned  Unanswered       NaN
# 765398                      MT  Unanswered  Unanswered       NaN
#
# [2 rows x 51 columns]
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       9547507704   05/01/2020            464              PPP
# 1       9777677704   05/01/2020            464              PPP
# 2       5791407702   05/01/2020           1013              PPP
# 3       6223567700   05/01/2020            920              PPP
# 4       9662437702   05/01/2020            101              PPP
# ...            ...          ...            ...              ...
# 766494  2665238309   01/21/2021            897              PPS
# 766495  4395967002   04/03/2020            897              PPP
# 766496  6985647108   04/14/2020            897              PPP
# 766497  9054647103   04/15/2020            897              PPP
# 766498  9184687004   04/09/2020            897              PPP
#
#                                              BorrowerName  \
# 0                                   SUMTER COATINGS, INC.
# 1                                   PLEASANT PLACES, INC.
# 2                                 BOYER CHILDREN'S CLINIC
# 3                                KIRTLEY CONSTRUCTION INC
# 4                                            AERO BOX LLC
# ...                                                   ...
# 766494                                RHOADES DENTAL P.C.
# 766495                           ROY E PAULSON, JR., P.C.
# 766496  SWEETWATER COUNTY CHILD DEVELOPMENTAL CENTER, ...
# 766497                                     EDEN LIFE CARE
# 766498                      S & S JOHNSON ENTERPRISES INC
#
#                                   BorrowerNameFingerprint  \
# 0                             coatings inc sumter sumter
# 1                   inc places pleasant charleston north
# 2                         boyer childrens clinic seattle
# 3                construction inc kirtley bernardino san
# 4                                       aero box llc a n
# ...                                                   ...
# 766494                     dental pc rhoades newcastle WY
# 766495                      e jr paulson pc roy casper WY
# 766496  center child county developmental inc sweetwat...
# 766497                         care eden life sheridan WY
# 766498         enterprises inc johnson s teton village WY
#
#                       BorrowerAddress      BorrowerCity BorrowerState  \
# 0               2410 Highway 15 South            Sumter           NaN
# 1                 7684 Southrail Road  North Charleston           NaN
# 2                    1850 BOYER AVE E           SEATTLE           NaN
# 3                1661 MARTIN RANCH RD    SAN BERNARDINO           NaN
# 4                                 NaN               NaN           NaN
# ...                               ...               ...           ...
# 766494                17 S Seneca Ave         Newcastle            WY
# 766495                 102 N. Kenwood            CASPER            WY
# 766496          1715 HITCHING POST DR       GREEN RIVER            WY
# 766497  30 N. Gould Street Suite 4000          SHERIDAN            WY
# 766498           7342 Granite Loop Rd     TETON VILLAGE            WY
#
#        BorrowerZip  ... HEALTH_CARE_PROCEED DEBT_INTEREST_PROCEED  \
# 0       29150-9662  ...                 NaN                   NaN
# 1       29420-9000  ...                 NaN                   NaN
# 2       98112-2922  ...                 NaN                   NaN
# 3       92407-1740  ...                 NaN                   NaN
# 4              NaN  ...                 NaN                   NaN
# ...            ...  ...                 ...                   ...
# 766494  82701-2816  ...                 NaN                   NaN
# 766495  82601-2724  ...                 NaN                   NaN
# 766496  82935-5783  ...                 NaN                   NaN
# 766497       82801  ...                 NaN                   NaN
# 766498  83025-0550  ...                 NaN                   NaN
#
#                        BusinessType  OriginatingLenderLocationID  \
# 0                       Corporation                        19248
# 1               Sole Proprietorship                        19248
# 2           Non-Profit Organization                         9551
# 3                       Corporation                         9551
# 4                               NaN                        57328
# ...                             ...                          ...
# 766494                  Corporation                        77248
# 766495                  Corporation                        42366
# 766496  Non-Profit Childcare Center                       122813
# 766497                  Corporation                        25901
# 766498     Subchapter S Corporation                        77193
#
#                             OriginatingLender  OriginatingLenderCity  \
# 0                                Synovus Bank               COLUMBUS
# 1                                Synovus Bank               COLUMBUS
# 2       Bank of America, National Association              CHARLOTTE
# 3       Bank of America, National Association              CHARLOTTE
# 4                The Huntington National Bank               COLUMBUS
# ...                                       ...                    ...
# 766494                  Pinnacle Bank-Wyoming                   CODY
# 766495                     Platte Valley Bank             TORRINGTON
# 766496             NebraskaLand National Bank           NORTH PLATTE
# 766497                    Small Business Bank                 LENEXA
# 766498                   Bank of Jackson Hole                JACKSON
#
#         OriginatingLenderState      Gender      Veteran NonProfit
# 0                           GA  Unanswered   Unanswered       NaN
# 1                           GA  Male Owned  Non-Veteran       NaN
# 2                           NC  Unanswered   Unanswered         Y
# 3                           NC  Unanswered   Unanswered       NaN
# 4                           OH  Unanswered   Unanswered       NaN
# ...                        ...         ...          ...       ...
# 766494                      WY  Unanswered   Unanswered       NaN
# 766495                      WY  Male Owned  Non-Veteran       NaN
# 766496                      NE  Unanswered   Unanswered         Y
# 766497                      KS  Unanswered   Unanswered       NaN
# 766498                      WY  Unanswered   Unanswered       NaN
#
# [766497 rows x 51 columns]

# %%
# calculate the dollars per job
dollars_per_job = ppp_data['CurrentApprovalAmount']/ppp_data['JobsReported']

# insert the new column into our original dataset
ppp_data.insert(3, 'Dollars per Job', dollars_per_job)

# %%
# use `ProcessingMethod` value to identify second-round loans
pps_loans = ppp_data[ppp_data['ProcessingMethod'] == 'PPS']

# select all second-round loans that have a value of $2M
pps_got_2M = pps_loans[pps_loans['CurrentApprovalAmount'] == 2000000.00]
print("Actual $2M second-round loans:")
print(pps_got_2M.shape)
# Out:
# Actual $2M second-round loans:
# (1459, 52)

# %%
# pull fingerprints of businesses approved for $2M second-round loans
biz_names = pd.unique(pps_got_2M['BorrowerNameFingerprint'])

# convert that list to a DataFrame
biz_names_df = pd.DataFrame(biz_names, columns=['BorrowerNameFingerprint'])

# create an array of the same length as `biz_names_df`; fill with flag value
fill_column = np.full((len(biz_names),1), '2Mil2ndRnd')
biz_names_df['GotSecond'] = fill_column

# now merge this new, two-column DataFrame back onto our full_data list
second_round_max = pd.merge(ppp_data, biz_names_df, on='BorrowerNameFingerprint')

# %%
# all loans whose fingerprints match those of businesses that got $2M
# in the second round should have `2Mil2ndRnd` in the `GotSecond` column
second_max_all_loans = second_round_max[
 second_round_max['GotSecond'] == '2Mil2ndRnd']

# sbould be 2x the number of businesses approved for $2M second-round
print('Total # of loans approved for most orgs that got $2M for second round:')
print(second_max_all_loans.shape)
# Out:
# Total # of loans approved for most orgs that got $2M for second round:
# (2634, 53)

# %%
# how much money were these businesses approved to get from the PPP, total?
total_funds = second_max_all_loans['CurrentApprovalAmount'].sum()
print("Total funds approved for identified orgs that could have " + \
 "second-round max:")
print(total_funds)
# Out:
# Total funds approved for identified orgs that could have second-round max:
# 6250357574.440001

# %%
# now, let's plot that new column on our selected dataset
# set the seaborn theme
sns.set_theme(style="whitegrid")

# the `matplotlib` `subplots()` to plot charts side by side
fig, ((row1col1)) = plt.subplots(nrows=1, ncols=1)

# plot the histogram of our date-based analysis
date_based = sns.histplot(data=second_max_all_loans, x='Dollars per Job',
 hue='ProcessingMethod', ax=row1col1)

# show the plots!
plt.show()
